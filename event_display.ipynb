# %%
# %matplotlib widget
from EventDisplay import EvDisp
from EventDisplay import list_entries

# %%
# Default run
run=15
subrun=9
event=260

# %%
# EvDisp will plot the events
# EvDisp(run, subrun, event, plane, data_file)


# Planes 0,1,2 -> U,V,Y
EvDisp(run,subrun,event,2,'mc')
# Out:
# No such event found! Please check that such an event exists.
# Displaying event: 260, subrun: 5, run: 14634
# <HDF5 group "/image2d/wire" (1 members)>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#look at metadata to get list of events

# %%
# print list of 10 entries
list_entries('mc', sliced = True, slice_val = 10)
#list_entries('mc') # prints all events
# Out:
# Event: 260, Subrun: 5, Run: 14634
# Event: 264, Subrun: 5, Run: 14634
# Event: 267, Subrun: 5, Run: 14634
# Event: 268, Subrun: 5, Run: 14634
# Event: 281, Subrun: 5, Run: 14634
# Event: 285, Subrun: 5, Run: 14634
# Event: 286, Subrun: 5, Run: 14634
# Event: 295, Subrun: 5, Run: 14634
# Event: 651, Subrun: 13, Run: 14634
# Event: 652, Subrun: 13, Run: 14634
# Event: 663, Subrun: 13, Run: 14634
